# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45a2-ai/pythonlab/blob/main/WEEK1/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##WEEK_1

# %% [markdown]
# python day1

# %%
print("hello,I'm Bala")
# Out:
# hello,I'm Bala

# %% [markdown]
# arthematic

# %%
print(2+4*7)
# Out:
# 30

# %% [markdown]
# basic operation

# %%
a=2
print(a)
# Out:
# 2

# %%
a=input()
# Out:
# 5

# %%
a=2
print(type(a))
# Out:
# <class 'int'>

# %%
a=input(input())
# Out:
# 5
# 56

# %%
a=input()+input()
print(a,a)
# Out:
# 3
# 6
# 36 36

# %%
print("hello");print("hi");print("bala")
# Out:
# hello
# hi
# bala

# %% [markdown]
# double slah gives integer value for float

# %%
a=5
print(a%2)
print(a/2)
# Out:
# 1
# 2.5

# %%
b=4.65
print(a//2)
# Out:
# 2

# %% [markdown]
# arethemaic operation
# addition +
# subtraction -
# multiplication *
# diviion /
# modilation %

# %%
print("hello")print("hi")
# Out:
#   File "/tmp/ipykernel_465/1097172971.py", line 1
#     print("hello")print("hi")
#                   ^
# SyntaxError: invalid syntax
