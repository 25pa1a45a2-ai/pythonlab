# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45a2-ai/pythonlab/blob/main/pythonlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##WEEK_1

# %% [markdown]
# python day1

# %%
print("hello,I'm Bala")
# Out:
# hello,I'm Bala

# %% [markdown]
# arthematic

# %%
print(2+4*7)
# Out:
# 30
