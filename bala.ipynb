# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45a2-ai/pythonlab/blob/main/bala.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## hello

# %% [markdown]
# data_types

# %%
x=3j
print(x)
print(type(x))
# Out:
# 3j
# <class 'complex'>

# %%
x={6,7,36}
print(x)
print(type(x))
# Out:
# {36, 6, 7}
# <class 'set'>
